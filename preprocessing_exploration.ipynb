# %%
import os
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from preprocessing_functions import *

# %%
images_pid, images_image, images_label, images_mask = read_images_to_array('data/images/')
images_label_string = convert_labels_to_strings(images_label)
# Out:
# 1070.mat
# 1071.mat
# 1072.mat
# 1073.mat
# 1074.mat
# 1075.mat
# 1076.mat
# 1203.mat
# 1204.mat
# 1205.mat
# 1206.mat
# 1207.mat
# 955.mat
# 956.mat
# 957.mat

# %%
# 15 images have shape other than 512 x 512 - they will not be included

# %% [markdown]
# # patient ids

# %%
# number of patients in the dataset and all datapoints
print(np.unique(images_pid).shape)
print(images_pid.shape)
# Out:
# (232,)
# (3049,)

# %%
# number of images per patient
pd.Series(images_pid).value_counts()
# Out:
# 778248515051505067    38
# 7782485349545252      37
# 778248534954525267    35
# 778248534849515366    34
# 778248524850524867    31
#                       ..
# 5656534948             1
# 5753575457             1
# 5755555751             1
# 494854535750           1
# 494949545754           1
# Length: 232, dtype: int64

# %% [markdown]
# # labels

# %%
print(images_label.shape)
print(np.unique(images_label).shape)
# Out:
# (3049,)
# (3,)

# %%
pd.Series(images_label_string).value_counts()
# Out:
# glioma             1426
# pituitary tumor     915
# meningioma          708
# dtype: int64

# %% [markdown]
# # sample images

# %%
plot_image(423, images_pid, images_image, images_label_string, images_mask)

# %%
plot_image(252, images_pid, images_image, images_label_string, images_mask)

# %%
plot_image(2342, images_pid, images_image, images_label_string, images_mask)

# %%
plot_image(1234, images_pid, images_image, images_label_string, images_mask)

# %%
plot_image(941, images_pid, images_image, images_label_string, images_mask)

# %%
plot_image(2950, images_pid, images_image, images_label_string, images_mask)
